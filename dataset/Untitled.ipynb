# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 1.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd
import openpyxl

df = pd.read_excel('ai_competition_noout.xlsx')
df = df.rename(columns={'date': 'date', 'flux': 'OT'})
df = df.dropna()
df.drop(df.index[2555:3090], inplace = True)
df
# Out:
#     date        OT
# 0      1  125.0810
# 1      2  125.4960
# 2      3  132.6010
# 3      4  134.9365
# 4      5  137.2720
# 5      6  130.2020
# 6      7  149.5830
# 7      8  154.6290
# 8      9  136.3020
# 9     10  143.2860
# 10    11  132.6440
# 11    12  130.2440
# 12    13  122.5740
# 13    14  114.4420
# 14    15  120.6260
# 15    16  111.6610
# 16    17  120.3040
# 17    18  133.0760
# 18    19  137.5370
# 19    20  141.5160
# 20    21  141.7420
# 21    22  137.6260
# 22    23  139.5840
# 23    24  133.9860
# 24    25  122.3700
# 25    26  126.1190
# 26    27  129.5435
# 27    28  129.7770
# 28    29  135.8850
# 29    30  142.1500
# 30    31  134.7260
# 31    32  154.2920
# 32    33  139.7630
# 33    34  142.4670
# 34    35  152.9490
# 35    36  154.9180
# 36    37  149.8180
# 37    38  150.7620
# 38    39  144.0170
# 39    40  141.5160
# 40    41  139.5390
# 41    42  130.9270
# 42    43  134.1600
# 43    44  126.1190
# 44    45  126.8700
# 45    46  139.5840
# ...

# %%
import pandas as pd
import openpyxl

df = pd.read_csv('ai_competition_noout.csv')
df = df.dropna()
df.drop(df.index[2555:3090], inplace = True)
df
# Out:
#             date        OT
# 0     2008-01-01   94.8000
# 1     2008-01-02   96.9300
# 2     2008-01-03   97.7100
# 3     2008-01-04   90.0900
# 4     2008-01-05   90.7400
# ...          ...       ...
# 4228  2022-12-27  120.4250
# 4229  2022-12-28  125.2050
# 4230  2022-12-29  126.9195
# 4231  2022-12-30  128.6340
# 4232  2022-12-31  143.6510
#
# [3698 rows x 2 columns]

# %%
df.to_csv('ai_competition_final_cut.csv', index = False)

# %%
df2 = pd.read_excel('ai_competition_test.xlsx')
df2 = df2.rename(columns={'date': 'date', 'flux': 'OT'})
df2.to_csv('ai_competition_test.csv', index = False)

# %%
#code to triple dataset

import pandas as pd

df = pd.read_csv('ai_competition_nonan.csv')

# Triple the length of the DataFrame
df_tripled = pd.concat([df] * 2, ignore_index=True)

# Create a new column 'date' with the re-allocated index values
df_tripled['date'] = range(len(df_tripled))

df_tripled.to_csv('ai_train_double.csv')

# %%
import matplotlib.pyplot as plt

df = pd.read_csv('ai_competition_nonan.csv')
plt.figure(figsize=(20, 4))
plt.plot(df['date'].iloc[1000:1500], df['OT'].iloc[1000:1500])
plt.show()

# %%
import numpy as np

def FFT(df, col, topn=2):
    fft = np.fft.fft(df[col])
    fft[topn:-topn] = 0
    ifft = np.fft.ifft(fft)
    return ifft

new = FFT(df, 'OT', 500)

plt.figure(figsize=(20, 4))
plt.plot(df['date'].iloc[1000:1500], new[1000:1500], c = 'orange')
#plt.plot(df['date'].iloc[1000:1500], df['OT'].iloc[1000:1500])
plt.show()
# Out:
# /Users/chaeyeonwoo/anaconda3/lib/python3.10/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/chaeyeonwoo/anaconda3/lib/python3.10/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
new
print(new[0])

new_float = [float(n) for n in new]

new_float
# Out:
# (112.06758176475464-0.04746278343117183j)
# /var/folders/zg/khmwlzfn0jl84fbmblcb12380000gn/T/ipykernel_6647/1764737275.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   new_float = [float(n) for n in new]
# [112.06758176475464,
#  103.44323578832719,
#  96.02600579275598,
#  91.08450298485265,
#  88.93930136828844,
#  88.97392749310717,
#  90.00228196862314,
#  90.81395491219007,
#  90.65836187918268,
#  89.47402062837207,
#  87.79434596406387,
#  86.40616008409631,
#  85.93681923630061,
#  86.55997076305277,
#  87.93905869613893,
#  89.41040022085375,
#  90.30042207400508,
#  90.2217998905448,
#  89.21806980263747,
#  87.70750368164379,
#  86.27218862185049,
#  85.40240682643743,
#  85.31333251372178,
#  85.90377128483595,
#  86.85327992420304,
#  87.79195912308859,
#  88.45442881681055,
#  88.75185360584581,
#  88.7466117171811,
#  88.56449718940058,
#  88.30403104802049,
#  87.99235901895184,
#  87.60226335032661,
#  87.10699406961658,
# ...

# %%
plt.figure(figsize=(20, 4))
plt.plot(df['date'].iloc[:], new[:], c = 'orange')
plt.show()
# Out:
# /Users/chaeyeonwoo/anaconda3/lib/python3.10/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/chaeyeonwoo/anaconda3/lib/python3.10/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#saving code

df_new = df

df['OT'] = new_float
df.to_csv('ai_train_fourier2.csv')
